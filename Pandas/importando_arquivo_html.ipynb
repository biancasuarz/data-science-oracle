# %%
import pandas as pd

# %%
dados_html = pd.read_html('/content/Lista de filmes de maior bilheteria – Wikipédia, a enciclopédia livre.html')

# %%
dados_html
# Out:
# [    Ranking   Ano                                    Filme  \
#  0         1  2009                                   Avatar
#  1         2  2019                     Vingadores: Ultimato
#  2         3  2022                Avatar: O Caminho da Água
#  3         4  1997                                  Titanic
#  4         5  2025                                 Ne Zha 2
#  ..      ...   ...                                      ...
#  95       96  2017                           Thor: Ragnarok
#  96       97  2012   A Saga Crepúsculo: Amanhecer - Parte 2
#  97       98  2023              Guardiões da Galáxia Vol. 3
#  98       99  2009  Transformers: A Vingança dos Derrotados
#  99      100  2002                             Homem-Aranha
#
#                               Distribuidor                 Diretor(a)  \
#  0                        20th Century Fox              James Cameron
#  1     Walt Disney Studios Motion Pictures  Joe Russo / Anthony Russo
# ...

# %%
type(dados_html)
# Out:
# list

# %%
len(dados_html)
# Out:
# 12

# %%
primeiros_filmes = dados_html[1]

# %%
primeiros_filmes
# Out:
#    Posição                                 Filme  \
# 0        1            Gone with the Wind[nota 1]
# 1        2                                Avatar
# 2        3                       Titanic[nota 2]
# 3        4                             Star Wars
# 4        5             Avengers: Endgame[nota 3]
# 5        6                    The Sound of Music
# 6        7            E.T. the Extra-Terrestrial
# 7        8                  The Ten Commandments
# 8        9                        Doctor Zhivago
# 9       10  Star Wars: The Force Awakens[nota 4]
#
#   Bilheteria mundial  Em dólares (2020 $)   Ano
# 0                           4 340 000 000  1939
# 1                           3 950 000 000  2009
# 2                           3 670 000 000  1997
# 3                           3 560 000 000  1977
# 4                           3 270 000 000  2019
# 5                           2 980 000 000  1965
# 6                           2 910 000 000  1982
# ...

# %%
primeiros_filmes.to_html('primeiros_filmes.html')

# %%
primeiros_filmes.to_csv('primeiros_filmes.csv')

# %%
pd.read_csv('primeiros_filmes.csv')
# Out:
#    Unnamed: 0  Posição                                 Filme  \
# 0           0        1            Gone with the Wind[nota 1]
# 1           1        2                                Avatar
# 2           2        3                       Titanic[nota 2]
# 3           3        4                             Star Wars
# 4           4        5             Avengers: Endgame[nota 3]
# 5           5        6                    The Sound of Music
# 6           6        7            E.T. the Extra-Terrestrial
# 7           7        8                  The Ten Commandments
# 8           8        9                        Doctor Zhivago
# 9           9       10  Star Wars: The Force Awakens[nota 4]
#
#   Bilheteria mundial  Em dólares (2020 $)   Ano
# 0                           4 340 000 000  1939
# 1                           3 950 000 000  2009
# 2                           3 670 000 000  1997
# 3                           3 560 000 000  1977
# 4                           3 270 000 000  2019
# ...
